# %% [markdown]
# # Paper Experiment

# %% [markdown]
# ## Force Signal

# %% [markdown]
# ### Paper Test Results

# %% [markdown]
# - Loss: 0.15507571878177778
# - Accuracy: 0.9458557865024377
# - Precision: 0.9648729446935725
# - Recall: 0.8872852233676976
# - F1 Score: 0.924453992123165
# - Start Mean Accuracies: 0.7619047619047619
# - End Mean Accuracies: 0.6190476190476191

# %% [markdown]
# ![eval_plot_9.png](attachment:eval_plot_9.png)

# %% [markdown]
# ### Conical Bent Results

# %% [markdown]
# - Loss: 0.24594515071887718
# - Accuracy: 0.9322485207100591
# - Precision: 0.9728923153444416
# - Recall: 0.8289891926255563
# - F1 Score: 0.8951945080091533
# - Start Mean Accuracies: 0.8947368421052632
# - End Mean Accuracies: 0.2894736842105263

# %% [markdown]
# ![eval_plot_10.png](attachment:eval_plot_10.png)

# %% [markdown]
# ### Anatomical Straight No Twist

# %% [markdown]
# - Loss: 1.475245875120163
# - Accuracy: 0.72018779342723
# - Precision: 0.4378259125551544
# - Recall: 0.8212942061700527
# - F1 Score: 0.5711669283097854
# - Start Mean Accuracies: 0.9428571428571428
# - End Mean Accuracies: 0.11428571428571428

# %% [markdown]
# ![eval_plot_12.png](attachment:eval_plot_12.png)

# %% [markdown]
# ### Without Clot (Conical Straight No Twist)

# %% [markdown]
# - Loss: 1.4467697143554688
# - Accuracy: 0.7936507936507936
# - Precision: 0.0
# - Recall: 0.0
# - F1 Score: 0.0
# - Start Mean Accuracies: 0.0
# - End Mean Accuracies: 0.3333333333333333

# %% [markdown]
# ![eval_plot_3.png](attachment:eval_plot_3.png)

# %% [markdown]
# ## Force + BandPower

# %% [markdown]
# ### Paper Test Results

# %% [markdown]
# - Loss: 0.38933822610193775
# - Accuracy: 0.9104938271604939
# - Precision: 0.976734166307626
# - Recall: 0.7793056033001031
# - F1 Score: 0.8669216061185469
# - Start Mean Accuracies: 0.9523809523809523
# - End Mean Accuracies: 0.47619047619047616

# %% [markdown]
# ### Conical Bent (No Twist)
# - Loss: 0.6402818089056956
# - Accuracy: 0.8748961872404681
# - Precision: 0.8919887381622729
# - Recall: 0.7383474576271186
# - F1 Score: 0.8079285962675322
# - Start Mean Accuracies: 0.5526315789473685
# - End Mean Accuracies: 0.18421052631578946

# %% [markdown]
# ### Anatomical Straight

# %% [markdown]
# - Loss: 1.0946589002651828
# - Accuracy: 0.8191011235955056
# - Precision: 0.5810151993117293
# - Recall: 0.7622272385252069
# - F1 Score: 0.6593978844589097
# - Start Mean Accuracies: 0.9142857142857143
# - End Mean Accuracies: 0.34285714285714286

# %% [markdown]
# ### Without Clot

# %% [markdown]
# - Loss: 4.987630526224772
# - Accuracy: 0.328537170263789
# - Precision: 0.0
# - Recall: 0.0
# - F1 Score: 0.0
# - Start Mean Accuracies: 0.0
# - End Mean Accuracies: 0.3333333333333333

# %% [markdown]
# ![eval_plot_3.png](attachment:eval_plot_3.png)

# %% [markdown]
# # Twist Experiment

# %% [markdown]
# ## Force Signal

# %% [markdown]
# ### Twist Anatomical (Bent)

# %% [markdown]
# - Loss: 0.5579681947179462
# - Accuracy: 0.8461447632542213
# - Precision: 0.8524923702950152
# - Recall: 0.6232800297508367
# - F1 Score: 0.7200859291084855
# - Start Mean Accuracies: 0.7391304347826086
# - End Mean Accuracies: 0.17391304347826086

# %% [markdown]
# ![eval_plot_20.png](attachment:eval_plot_20.png)

# %% [markdown]
# ### Conical Bent Twist

# %% [markdown]
# - Loss: 0.29918193724006414
# - Accuracy: 0.8785117691723614
# - Precision: 0.9791376912378303
# - Recall: 0.602224123182207
# - F1 Score: 0.7457627118644068
# - Start Mean Accuracies: 0.875
# - End Mean Accuracies: 0.25

# %% [markdown]
# ![eval_plot_6.png](attachment:eval_plot_6.png)

# %% [markdown]
# ### Conical No Twist (Straight)

# %% [markdown]
# - Loss: 0.7571456458638696
# - Accuracy: 0.8907027672705554
# - Precision: 0.773497688751926
# - Recall: 0.9330855018587361
# - F1 Score: 0.8458298230834035
# - Start Mean Accuracies: 1.0
# - End Mean Accuracies: 0.6470588235294118

# %% [markdown]
# ![eval_plot_5.png](attachment:eval_plot_5.png)

# %% [markdown]
# ### No Clot (Conical Straight No Twist)

# %% [markdown]
# - Loss: 0.6965517401695251
# - Accuracy: 1.0
# - Precision: 0.0
# - Recall: 0.0
# - F1 Score: 0.0
# - Start Mean Accuracies: 1.0
# - End Mean Accuracies: 1.0

# %% [markdown]
# ![eval_plot_3.png](attachment:eval_plot_3.png)

# %% [markdown]
# ### Paper Data

# %% [markdown]
# - Loss: 0.5809805853865467
# - Accuracy: 0.7930146006298311
# - Precision: 0.8036247951412321
# - Recall: 0.5849003648610721
# - F1 Score: 0.6770355329949238
# - Start Mean Accuracies: 0.7980769230769231
# - End Mean Accuracies: 0.2692307692307692

# %% [markdown]
# ![eval_plot_10.png](attachment:eval_plot_10.png)

# %% [markdown]
# ## Force + BandPower

# %% [markdown]
# ### Twist Anatomical (Bent)

# %% [markdown]
# - Loss: 0.8265296680771786
# - Accuracy: 0.7819530876017233
# - Precision: 0.6536412078152753
# - Recall: 0.6847785634536658
# - F1 Score: 0.6688476917484552
# - Start Mean Accuracies: 0.5217391304347826
# - End Mean Accuracies: 0.08695652173913043

# %% [markdown]
# ### Conical Bent Twist
# - Loss: 0.6109188459813595
# - Accuracy: 0.8549078980570275
# - Precision: 0.7690217391304348
# - Recall: 0.7262617621899059
# - F1 Score: 0.7470303563572371
# - Start Mean Accuracies: 0.625
# - End Mean Accuracies: 0.0

# %% [markdown]
# ### Conical Straight No Twist
# - Loss: 1.9452145169763004
# - Accuracy: 0.45461847389558235
# - Precision: 0.37233549582947173
# - Recall: 0.9956629491945477
# - F1 Score: 0.5419898819561552
# - Start Mean Accuracies: 0.058823529411764705
# - End Mean Accuracies: 0.0

# %% [markdown]
# ### No Clot

# %% [markdown]
# - Loss: 2.5858957767486572
# - Accuracy: 0.07645631067961164
# - Precision: 0.0
# - Recall: 0.0
# - F1 Score: 0.0
# - Start Mean Accuracies: 0.0
# - End Mean Accuracies: 0.6666666666666666

# %% [markdown]
# ### Paper Data

# %% [markdown]
# - Loss: 1.897791516322356
# - Accuracy: 0.45736002966258804
# - Precision: 0.40963366566195225
# - Recall: 0.9916508805163825
# - F1 Score: 0.5797731607769141
# - Start Mean Accuracies: 0.0
# - End Mean Accuracies: 0.028846153846153848

# %% [markdown]
# ![eval_plot_2.png](attachment:eval_plot_2.png)

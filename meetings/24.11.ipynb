# %% [markdown]
# # Images

# %% [markdown]
# ## Clot detection
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Wire detectin
# ### Absolute diff with first image
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exponential Moving Average

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Notes
# - make labels gradual ? not 0 and 1
# - randomized window selection ?

# %% [markdown]
# - add dimension frequency features + images
# - test without clot

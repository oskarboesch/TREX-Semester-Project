# %% [markdown]
# # Basic Data Analysis
# ## Errors with some logs ?
# discard logs 7, 158, 174, errors ? timestamps goes from 4293 to 0

# %% [markdown]
# ## Stiffness
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Start and End times

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Modeling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Capture d’écran 2025-11-13 à 15.24.30.png](<attachment:Capture d’écran 2025-11-13 à 15.24.30.png>)
# Overall bad accuracies very dependent on initialization, difficult to reproduce entirely the global search optimization method...
# Could be further looked into

# %% [markdown]
# # RNNs
# ## Define in-clot time series

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# RNN predict the next step from any sequence of data

# %% [markdown]
# ### Different downsampling frequencies, forward, backward and both directions

# %% [markdown]
# ![Capture d’écran 2025-11-13 à 15.27.00.png](<attachment:Capture d’écran 2025-11-13 à 15.27.00.png>)

# %% [markdown]
# ### Predictions are probabilities

# %% [markdown]
# #### Forward Example of prediction

# %% [markdown]
# ![eval_plot_10.png](attachment:eval_plot_10.png)

# %% [markdown]
# # Next steps
# ## Data
# - A lot of hyperparameter optimization can be done
# - We can try to use additional metrics, what could be relevant ?
# - Try without standardization see the impact ?
# - Add images into the pipeline
# - Add other trials, 45 degrees ?
# ## Real-time prediction
# - We can simulate real time prediction by feeding the curve in multiple timesteps to observe the result of the model
# ## Prediction
# - Study the accuracy per category of clot ? per angle
# - Try to predict stiffness of the clot from curve ? predict pressure ?

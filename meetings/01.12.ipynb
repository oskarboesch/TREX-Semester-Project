# %% [markdown]
# # To do
# - Frequency Analysis of in and out of clot as well as transision
# - Include relevant frequency metrics in model per window
# - Image Segmentation
# - Include Image in CNN

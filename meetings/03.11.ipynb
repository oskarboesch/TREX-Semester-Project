# %% [markdown]
# # Questions
# - What would be the next dataset ?
# - How can I access the data ?
# - Do we have access to the code of the paper ?

# %% [markdown]
# # Notes

# %% [markdown]
# ## To do
# - Start with data from paper, try and reproduce results in python ?
# ## Images addition
# - simply binary images to find in real time ?
# - study compression and prediction segmentation of the wire ?
# - Use ML on the data of the experiement ?
